# %%
import pandas as pd

# %%
ls
# Out:
# 'Data Aggregation.ipynb'   ne.xlsx              World_Happiness_2015.csv*
#  f500.csv*                'Pandas Cont.ipynb'   World_Happiness_2016.csv*
#  laptops.csv*              PANDAS.ipynb         World_Happiness_2017.csv*
#  newData.xlsx              Untitled.ipynb

# %%
happiness15 = pd.read_csv("World_Happiness_2015.csv")
happiness15
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
happiness16 = pd.read_csv("World_Happiness_2016.csv")
happiness17 = pd.read_csv("World_Happiness_2015.csv")
happiness15["year"] = 2015
happiness16["year"] = 2016
happiness17["year"] = 2017

# %%
three15 = happiness15[["Country","Happiness Score","year"]].head(3)
three16 = happiness16[["Country","Happiness Score","year"]].head(3)
three17 = happiness17[["Country","Happiness Score","year"]].head(3)

# %%
three15
# Out:
#        Country  Happiness Score  year
# 0  Switzerland            7.587  2015
# 1      Iceland            7.561  2015
# 2      Denmark            7.527  2015

# %%
three16
# Out:
#        Country  Happiness Score  year
# 0      Denmark            7.526  2016
# 1  Switzerland            7.509  2016
# 2      Iceland            7.501  2016

# %%
pd.concat([three15,three16],axis = 0, ignore_index= True)
# Out:
#        Country  Happiness Score  year
# 0  Switzerland            7.587  2015
# 1      Iceland            7.561  2015
# 2      Denmark            7.527  2015
# 3      Denmark            7.526  2016
# 4  Switzerland            7.509  2016
# 5      Iceland            7.501  2016

# %%
pd.concat([three15,three16],axis = 1, ignore_index= True)
# Out:
#              0      1     2            3      4     5
# 0  Switzerland  7.587  2015      Denmark  7.526  2016
# 1      Iceland  7.561  2015  Switzerland  7.509  2016
# 2      Denmark  7.527  2015      Iceland  7.501  2016

# %%
three15 = happiness15[["Country","Happiness Score","Standard Error","year"]].head(3)
three16 = happiness16[["Country","Happiness Score","year"]].head(3)

# %%
pd.concat([three15,three16],axis = 0)
# Out:
#        Country  Happiness Score  Standard Error  year
# 0  Switzerland            7.587         0.03411  2015
# 1      Iceland            7.561         0.04884  2015
# 2      Denmark            7.527         0.03328  2015
# 0      Denmark            7.526             NaN  2016
# 1  Switzerland            7.509             NaN  2016
# 2      Iceland            7.501             NaN  2016

# %%
pd.concat([three15,three16],axis = 1)
# Out:
#        Country  Happiness Score  Standard Error  year      Country  \
# 0  Switzerland            7.587         0.03411  2015      Denmark
# 1      Iceland            7.561         0.04884  2015  Switzerland
# 2      Denmark            7.527         0.03328  2015      Iceland
#
#    Happiness Score  year
# 0            7.526  2016
# 1            7.509  2016
# 2            7.501  2016

# %%
happiness17.rename({"Happiness Score":"Happiness Score"},axis = 1,inplace = True)

# %%
three15 = happiness15[["Country","Happiness Score","year"]].head(3)
three16 = happiness16[["Country","Happiness Score","year"]].head(3)

# %%
pd.merge(right = three17,left = three16, how="inner",on="Country",suffixes = ("2016","2017"))
# Out:
#        Country  Happiness Score2016  year2016  Happiness Score2017  year2017
# 0      Denmark                7.526      2016                7.527      2017
# 1  Switzerland                7.509      2016                7.587      2017
# 2      Iceland                7.501      2016                7.561      2017
