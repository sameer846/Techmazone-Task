# %%
import pandas as pd
data = pd.read_csv("laptops.csv",encoding = "windows-1251") #latin-1

# %%
data
# Out:
#      Manufacturer                           Model Name            Category  \
# 0           Apple                          MacBook Pro           Ultrabook
# 1           Apple                          Macbook Air           Ultrabook
# 2              HP                               250 G6            Notebook
# 3           Apple                          MacBook Pro           Ultrabook
# 4           Apple                          MacBook Pro           Ultrabook
# ...           ...                                  ...                 ...
# 1298       Lenovo                       Yoga 500-14ISK  2 in 1 Convertible
# 1299       Lenovo                       Yoga 900-13ISK  2 in 1 Convertible
# 1300       Lenovo                   IdeaPad 100S-14IBR            Notebook
# 1301           HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1302         Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
#      Screen Size                                      Screen  \
# ...

# %%
data.head(5)
# Out:
#   Manufacturer   Model Name   Category Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook       13.3"
# 1        Apple  Macbook Air  Ultrabook       13.3"
# 2           HP       250 G6   Notebook       15.6"
# 3        Apple  MacBook Pro  Ultrabook       15.4"
# 4        Apple  MacBook Pro  Ultrabook       13.3"
#
#                                Screen                         CPU   RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                Storage                           GPU Operating System  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS
# 1  128GB Flash Storage        Intel HD Graphics 6000            macOS
# ...

# %%
data["Manufacturer"].value_counts()
# Out:
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: Manufacturer, dtype: int64

# %%
data.columns
# Out:
# Index(['Manufacturer', 'Model Name', 'Category', 'Screen Size', 'Screen',
#        'CPU', 'RAM', ' Storage', 'GPU', 'Operating System',
#        'Operating System Version', 'Weight', 'Price (Euros)'],
#       dtype='object')

# %%
"   adeel".strip() #STARTING AND ENDING
# Out:
# 'adeel'

# %%
"-----ashfiulas--fnlaksnfq----".strip("-")
# Out:
# ['ashfiulas', '', 'fnlaksnfq']

# %%
data.columns = data.columns.str.strip().str.replace("(","").str.replace(")","")\
.str.replace(" ","_").\
str.replace("Operating_System","os").str.lower()
# Out:
# /tmp/ipykernel_36698/127110213.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data.columns = data.columns.str.strip().str.replace("(","").str.replace(")","")\
# /tmp/ipykernel_36698/127110213.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data.columns = data.columns.str.strip().str.replace("(","").str.replace(")","")\

# %%
data.columns
# Out:
# Index(['Manufacturer', 'Model Name', 'Category', 'Screen Size', 'Screen',
#        'CPU', 'RAM', ' Storage', 'GPU', 'Operating System',
#        'Operating System Version', 'Weight', 'Price (Euros)'],
#       dtype='object')

# %%
data.head(5)
# Out:
#   manufacturer   model_name   category screen_size  \
# 0        Apple  MacBook Pro  Ultrabook       13.3"
# 1        Apple  Macbook Air  Ultrabook       13.3"
# 2           HP       250 G6   Notebook       15.6"
# 3        Apple  MacBook Pro  Ultrabook       15.4"
# 4        Apple  MacBook Pro  Ultrabook       13.3"
#
#                                screen                         cpu   ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                storage                           gpu     os os_version  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS        NaN
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS        NaN
# ...

# %%
data["screen_size"] == "13.3\""
# Out:
# 0        True
# 1        True
# 2       False
# 3       False
# 4        True
#         ...
# 1298    False
# 1299     True
# 1300    False
# 1301    False
# 1302    False
# Name: screen_size, Length: 1303, dtype: bool

# %%
data["gpu_company"] = data["gpu"].str.split(" ",n=1,expand=True)[0]

# %%
data["gpu_company"].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: gpu_company, dtype: int64

# %%
data["cpu_company"] = data["cpu"].str.split(n=1,expand=True)[0]

# %%
data["cpu_company"].value_counts()
# Out:
# Intel      1240
# AMD          62
# Samsung       1
# Name: cpu_company, dtype: int64
