# %%
import requests

# %%
base_site = 'https://en.wikipedia.org/wiki/Music'
response = requests.get(base_site)
response
# Out:
# <Response [200]>

# %%
response.status_code
# Out:
# 200

# %%
response.ok
# Out:
# True

# %%
content = response.text

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(content,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Music - Wikipedia</title>
# ...

# %%
soup.find('head')
# Out:
# <head>
# <meta charset="utf-8"/>
# <title>Music - Wikipedia</title>
# ...

# %%
print(soup.find('video'))
# Out:
# None

# %%
soup.find('a')
# Out:
# <a id="top"></a>

# %%
links = soup.find_all('a')
links
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_374197/2039309919.py in <module>
#       1 links = soup.find_all('a')
# ----> 2 links.text
#
# ~/anaconda3/lib/python3.9/site-packages/bs4/element.py in __getattr__(self, key)
#    2251     def __getattr__(self, key):
#    2252         """Raise a helpful exception to explain a common code fix."""
# -> 2253         raise AttributeError(
#    2254             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2255         )
#
# AttributeError: ResultSet object has no attribute 'text'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
soup.find_all('a',title="Tempo")
# Out:
# [<a href="/wiki/Tempo" title="Tempo">accelerando</a>]

# %%
soup.find_all('a',{"title":"Tempo"})
# Out:
# [<a href="/wiki/Tempo" title="Tempo">accelerando</a>]

# %%
soup.find_all('table',class_="box-Multiple_issues")
# Out:
# [<table class="box-Multiple_issues plainlinks metadata ambox ambox-content ambox-multiple_issues compact-ambox" role="presentation"><tbody><tr><td class="mbox-image"><div class="mbox-image-div"><img alt="" data-file-height="40" data-file-width="40" decoding="async" height="40" src="//upload.wikimedia.org/wikipedia/en/thumb/b/b4/Ambox_important.svg/40px-Ambox_important.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/b/b4/Ambox_important.svg/60px-Ambox_important.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/b/b4/Ambox_important.svg/80px-Ambox_important.svg.png 2x" width="40"/></div></td><td class="mbox-text"><div class="mbox-text-span"><div class="multiple-issues-text mw-collapsible"><b>This article has multiple issues.</b> Please help <b><a class="external text" href="https://en.wikipedia.org/w/index.php?title=Music&amp;action=edit">improve it</a></b> or discuss these issues on the <b><a href="/wiki/Talk:Music" title="Talk:Music">talk page</a></b>. <small><i>(<a h
# ...

# %%
soup.find_all('table',{'class':"box-Multiple_issues"})
# Out:
# [<table class="box-Multiple_issues plainlinks metadata ambox ambox-content ambox-multiple_issues compact-ambox" role="presentation"><tbody><tr><td class="mbox-image"><div class="mbox-image-div"><img alt="" data-file-height="40" data-file-width="40" decoding="async" height="40" src="//upload.wikimedia.org/wikipedia/en/thumb/b/b4/Ambox_important.svg/40px-Ambox_important.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/b/b4/Ambox_important.svg/60px-Ambox_important.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/b/b4/Ambox_important.svg/80px-Ambox_important.svg.png 2x" width="40"/></div></td><td class="mbox-text"><div class="mbox-text-span"><div class="multiple-issues-text mw-collapsible"><b>This article has multiple issues.</b> Please help <b><a class="external text" href="https://en.wikipedia.org/w/index.php?title=Music&amp;action=edit">improve it</a></b> or discuss these issues on the <b><a href="/wiki/Talk:Music" title="Talk:Music">talk page</a></b>. <small><i>(<a h
# ...

# %%
a = links[24]

# %%
a.text
# Out:
# 'Learn how and when to remove this template message'

# %%
a['href']
# Out:
# '/wiki/Help:Maintenance_template_removal'

# %%
a['class']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_374197/3309424716.py in <module>
# ----> 1 a['class']
#
# ~/anaconda3/lib/python3.9/site-packages/bs4/element.py in __getitem__(self, key)
#    1484         """tag[key] returns the value of the 'key' attribute for the Tag,
#    1485         and throws an exception if it's not there."""
# -> 1486         return self.attrs[key]
#    1487
#    1488     def __iter__(self):
#
# KeyError: 'class'

# %%
print(a.get('class'))
# Out:
# None

# %%
a.attrs
# Out:
# {'href': '/wiki/Help:Maintenance_template_removal',
#  'title': 'Help:Maintenance template removal'}

# %%
div = soup.find('table',{'class':'box-Multiple_issues'})
div.attrs
# Out:
# {'class': ['box-Multiple_issues',
#   'plainlinks',
#   'metadata',
#   'ambox',
#   'ambox-content',
#   'ambox-multiple_issues',
#   'compact-ambox'],
#  'role': 'presentation'}

# %%
link = links[22]
link
# Out:
# <a href="/wiki/Help:Section#Subsections" title="Help:Section">subheadings</a>

# %%
link.text
# Out:
# 'subheadings'

# %%
base_site+link['href']
# Out:
# 'https://en.wikipedia.org/wiki/Music/wiki/Help:Section#Subsections'

# %%
from urllib.parse import urljoin

# %%
base_site
# Out:
# 'https://en.wikipedia.org/wiki/Music'

# %%
rel_url = link['href']
rel_url
# Out:
# '/wiki/Help:Section#Subsections'

# %%
full_url = urljoin(base_site,rel_url)
full_url
# Out:
# 'https://en.wikipedia.org/wiki/Help:Section#Subsections'

# %%
[i.get('href') for i in links]
# Out:
# [None,
#  '/wiki/Wikipedia:Protection_policy#semi',
#  '#mw-head',
#  '#searchInput',
#  '/wiki/Music_(disambiguation)',
#  'https://en.wikipedia.org/w/index.php?title=Music&action=edit',
#  '/wiki/Talk:Music',
#  '/wiki/Help:Maintenance_template_removal',
#  '/wiki/File:Question_book-new.svg',
#  '/wiki/Wikipedia:Verifiability',
#  'https://en.wikipedia.org/w/index.php?title=Music&action=edit',
#  '/wiki/Help:Referencing_for_beginners',
#  '//www.google.com/search?as_eq=wikipedia&q=%22Music%22',
#  '//www.google.com/search?tbm=nws&q=%22Music%22+-wikipedia&tbs=ar:1',
#  '//www.google.com/search?&q=%22Music%22&tbs=bkt:s&tbm=bks',
#  '//www.google.com/search?tbs=bks:1&q=%22Music%22+-wikipedia',
#  '//scholar.google.com/scholar?q=%22Music%22',
#  'https://www.jstor.org/action/doBasicSearch?Query=%22Music%22&acc=on&wc=on',
#  '/wiki/Help:Maintenance_template_removal',
#  '/wiki/Wikipedia:Article_size',
#  '/wiki/Wikipedia:Splitting',
#  '/wiki/Wikipedia:Summary_style',
# ...

# %%
relative_ulrs = [i.get('href') for i in links if i.get('href') != None]
relative_ulrs
# Out:
# ['/wiki/Wikipedia:Protection_policy#semi',
#  '#mw-head',
#  '#searchInput',
#  '/wiki/Music_(disambiguation)',
#  'https://en.wikipedia.org/w/index.php?title=Music&action=edit',
#  '/wiki/Talk:Music',
#  '/wiki/Help:Maintenance_template_removal',
#  '/wiki/File:Question_book-new.svg',
#  '/wiki/Wikipedia:Verifiability',
#  'https://en.wikipedia.org/w/index.php?title=Music&action=edit',
#  '/wiki/Help:Referencing_for_beginners',
#  '//www.google.com/search?as_eq=wikipedia&q=%22Music%22',
#  '//www.google.com/search?tbm=nws&q=%22Music%22+-wikipedia&tbs=ar:1',
#  '//www.google.com/search?&q=%22Music%22&tbs=bkt:s&tbm=bks',
#  '//www.google.com/search?tbs=bks:1&q=%22Music%22+-wikipedia',
#  '//scholar.google.com/scholar?q=%22Music%22',
#  'https://www.jstor.org/action/doBasicSearch?Query=%22Music%22&acc=on&wc=on',
#  '/wiki/Help:Maintenance_template_removal',
#  '/wiki/Wikipedia:Article_size',
#  '/wiki/Wikipedia:Splitting',
#  '/wiki/Wikipedia:Summary_style',
# ...

# %%
full_urls = [urljoin(base_site, i) for i in relative_ulrs]
full_urls
# Out:
# ['https://en.wikipedia.org/wiki/Wikipedia:Protection_policy#semi',
#  'https://en.wikipedia.org/wiki/Music#mw-head',
#  'https://en.wikipedia.org/wiki/Music#searchInput',
#  'https://en.wikipedia.org/wiki/Music_(disambiguation)',
#  'https://en.wikipedia.org/w/index.php?title=Music&action=edit',
#  'https://en.wikipedia.org/wiki/Talk:Music',
#  'https://en.wikipedia.org/wiki/Help:Maintenance_template_removal',
#  'https://en.wikipedia.org/wiki/File:Question_book-new.svg',
#  'https://en.wikipedia.org/wiki/Wikipedia:Verifiability',
#  'https://en.wikipedia.org/w/index.php?title=Music&action=edit',
#  'https://en.wikipedia.org/wiki/Help:Referencing_for_beginners',
#  'https://www.google.com/search?as_eq=wikipedia&q=%22Music%22',
#  'https://www.google.com/search?tbm=nws&q=%22Music%22+-wikipedia&tbs=ar:1',
#  'https://www.google.com/search?&q=%22Music%22&tbs=bkt:s&tbm=bks',
#  'https://www.google.com/search?tbs=bks:1&q=%22Music%22+-wikipedia',
# ...

# %%
internal_links = [url for url in full_urls if 'wikipedia.org' not in url]
internal_links
# Out:
# ['https://www.google.com/search?as_eq=wikipedia&q=%22Music%22',
#  'https://www.google.com/search?tbm=nws&q=%22Music%22+-wikipedia&tbs=ar:1',
#  'https://www.google.com/search?&q=%22Music%22&tbs=bkt:s&tbm=bks',
#  'https://www.google.com/search?tbs=bks:1&q=%22Music%22+-wikipedia',
#  'https://scholar.google.com/scholar?q=%22Music%22',
#  'https://www.jstor.org/action/doBasicSearch?Query=%22Music%22&acc=on&wc=on',
#  'https://en.wiktionary.org/wiki/music',
#  'https://en.wiktionary.org/wiki/musike',
#  'https://en.wiktionary.org/wiki/%CE%BC%CE%BF%CF%85%CF%83%CE%B9%CE%BA%CE%AE#Ancient_Greek#Ancient_Greek',
#  'https://en.wiktionary.org/wiki/%CF%84%CE%AD%CF%87%CE%BD%CE%B7#Ancient_Greek#Ancient_Greek',
#  'https://www.google.com/search?as_eq=wikipedia&q=%22Music%22',
#  'https://www.google.com/search?tbm=nws&q=%22Music%22+-wikipedia&tbs=ar:1',
#  'https://www.google.com/search?&q=%22Music%22&tbs=bkt:s&tbm=bks',
#  'https://www.google.com/search?tbs=bks:1&q=%22Music%22+-wikipedia',
# ...

# %%
for i in internal_links:
    print(i)
# Out:
# https://www.google.com/search?as_eq=wikipedia&q=%22Music%22
# https://www.google.com/search?tbm=nws&q=%22Music%22+-wikipedia&tbs=ar:1
# https://www.google.com/search?&q=%22Music%22&tbs=bkt:s&tbm=bks
# https://www.google.com/search?tbs=bks:1&q=%22Music%22+-wikipedia
# https://scholar.google.com/scholar?q=%22Music%22
# https://www.jstor.org/action/doBasicSearch?Query=%22Music%22&acc=on&wc=on
# https://en.wiktionary.org/wiki/music
# https://en.wiktionary.org/wiki/musike
# https://en.wiktionary.org/wiki/%CE%BC%CE%BF%CF%85%CF%83%CE%B9%CE%BA%CE%AE#Ancient_Greek#Ancient_Greek
# https://en.wiktionary.org/wiki/%CF%84%CE%AD%CF%87%CE%BD%CE%B7#Ancient_Greek#Ancient_Greek
# https://www.google.com/search?as_eq=wikipedia&q=%22Music%22
# https://www.google.com/search?tbm=nws&q=%22Music%22+-wikipedia&tbs=ar:1
# https://www.google.com/search?&q=%22Music%22&tbs=bkt:s&tbm=bks
# https://www.google.com/search?tbs=bks:1&q=%22Music%22+-wikipedia
# https://scholar.google.com/scholar?q=%22Music%22
# ...

# %%
base_site = 'https://www.espncricinfo.com/rankings/content/page/211271.html'
response = requests.get(base_site)
response
# Out:
# <Response [200]>

# %%
content = response.text

# %%
soup = BeautifulSoup(content,'html.parser')

# %%
tables = soup.find_all('table',{'class':'StoryengineTable'})

# %%
table = tables[1]
table
# Out:
# <table class="StoryengineTable">
# <caption>22 July 2022</caption>
# <tr class="head">
# <th class="left">Pos</th>
# <th class="left">Team</th>
# <th class="left">Matches</th>
# <th class="left">Points</th>
# <th class="left">Rating</th>
# </tr>
# <tr>
# <td class="left">1</td>
# <td class="left">New Zealand</td>
# <td class="left">15</td>
# <td class="left">1913</td>
# <td class="left">128</td>
# </tr>
# <tr>
# <td class="left">2</td>
# <td class="left">England</td>
# <td class="left">27</td>
# <td class="left">3226</td>
# <td class="left">119</td>
# </tr>
# <tr>
# <td class="left">3</td>
# <td class="left">India</td>
# <td class="left">26</td>
# <td class="left">2845</td>
# <td class="left">109</td>
# </tr>
# <tr>
# <td class="left">4</td>
# <td class="left">Pakistan</td>
# <td class="left">19</td>
# <td class="left">2005</td>
# <td class="left">106</td>
# </tr>
# <tr>
# <td class="left">5</td>
# <td class="left">Australia</td>
# <td class="left">23</td>
# ...

# %%
td = table.find_all('td')
td
# Out:
# [<td class="left">1</td>,
#  <td class="left">New Zealand</td>,
#  <td class="left">15</td>,
#  <td class="left">1913</td>,
#  <td class="left">128</td>,
#  <td class="left">2</td>,
#  <td class="left">England</td>,
#  <td class="left">27</td>,
#  <td class="left">3226</td>,
#  <td class="left">119</td>,
#  <td class="left">3</td>,
#  <td class="left">India</td>,
#  <td class="left">26</td>,
#  <td class="left">2845</td>,
#  <td class="left">109</td>,
#  <td class="left">4</td>,
#  <td class="left">Pakistan</td>,
#  <td class="left">19</td>,
#  <td class="left">2005</td>,
#  <td class="left">106</td>,
#  <td class="left">5</td>,
#  <td class="left">Australia</td>,
#  <td class="left">23</td>,
#  <td class="left">2325</td>,
#  <td class="left">101</td>,
#  <td class="left">6</td>,
#  <td class="left">South Africa</td>,
#  <td class="left">21</td>,
#  <td class="left">2111</td>,
#  <td class="left">101</td>,
#  <td class="left">7</td>,
#  <td class="left">Bangladesh</td>,
# ...

# %%
lst = []
for i in range(20):
    data = td[5*i:5*(i+1)]
    data = [i.text for i in data]
    print(data)
    lst.append(data)
# Out:
# ['1', 'New Zealand', '15', '1913', '128']
# ['2', 'England', '27', '3226', '119']
# ['3', 'India', '26', '2845', '109']
# ['4', 'Pakistan', '19', '2005', '106']
# ['5', 'Australia', '23', '2325', '101']
# ['6', 'South Africa', '21', '2111', '101']
# ['7', 'Bangladesh', '27', '2639', '98']
# ['8', 'Sri Lanka', '29', '2658', '92']
# ['9', 'West Indies', '36', '2503', '70']
# ['10', 'Afghanistan', '16', '1071', '67']
# ['11', 'Ireland', '23', '1214', '53']
# ['12', 'Scotland', '22', '990', '45']
# ['13', 'UAE', '19', '727', '38']
# ['14', 'Netherlands', '18', '603', '34']
# ['15', 'Zimbabwe', '17', '539', '32']
# ['16', 'Oman', '30', '919', '31']
# ['17', 'USA', '20', '544', '27']
# ['18', 'Namibia', '15', '369', '25']
# ['19', 'Nepal', '22', '331', '15']
# ['20', 'PNG', '22', '134', '6']
