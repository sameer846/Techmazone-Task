# %%
import pandas as pd

# %%
df = pd.read_excel("Aged payable schedule - October 2021.xlsx",sheet_name="Creditors Oct21 v051121")

# %%
df
# Out:
#          Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3         Unnamed: 4  \
# 0            Vendor        NaN        NaN        NaN              27145
# 1      Company Code        NaN        NaN        NaN               3440
# 2               NaN        NaN        NaN        NaN                NaN
# 3              Name        NaN        NaN        NaN  Bjorn Thorsen A/S
# 4              City        NaN        NaN        NaN           Hellerup
# ...             ...        ...        ...        ...                ...
# 999             NaN        NaN         St  Reference         Assignment
# 1000            NaN        NaN        NaN        NaN                NaN
# 1001            NaN        ***        NaN        NaN                NaN
# 1002            NaN        NaN        NaN        NaN                NaN
# 1003            NaN        NaN        NaN        NaN                NaN
#
#       Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 11  \
# ...

# %%
cols = df.iloc[7]

# %%
cols[0] = "Vendor"
cols[1] = "Name"

# %%
df.columns = cols

# %%
df.columns
# Out:
# Index(['Vendor', 'Name', 'St', 'Reference', 'Assignment', 'DocumentNo', 'Typ',
#        'Doc. Date', 'S', 'DD', '   Amount in DC', 'Curr', 'Clrng doc.',
#        'Amt in loc.cur.', 'LCu', 'Text', 'Net due dt', 'PBk', 'PM',
#        'Curr.cash disc.', 'Cash disc. amt LC'],
#       dtype='object', name=7)

# %%
indexes = df[df["St"]=="St"].index

# %%
indexes
# Out:
# Int64Index([  7,  24,  47,  77, 116, 132, 147, 172, 193, 213, 229, 266, 283,
#             298, 313, 328, 343, 358, 380, 412, 461, 477, 492, 508, 525, 540,
#             555, 582, 601, 621, 637, 655, 698, 713, 737, 761, 776, 793, 808,
#             823, 838, 855, 870, 885, 903, 940, 964, 981, 999],
#            dtype='int64')

# %%
df.drop(indexes,inplace = True)

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
# 7           Vendor Name   St Reference         Assignment DocumentNo  Typ  \
# 0           Vendor  NaN  NaN       NaN              27145        NaN  NaN
# 1     Company Code  NaN  NaN       NaN               3440        NaN  NaN
# 2              NaN  NaN  NaN       NaN                NaN        NaN  NaN
# 3             Name  NaN  NaN       NaN  Bjorn Thorsen A/S        NaN  NaN
# 4             City  NaN  NaN       NaN           Hellerup        NaN  NaN
# ..             ...  ...  ...       ...                ...        ...  ...
# 950            NaN  NaN  NaN       NaN                NaN        NaN  NaN
# 951            NaN  NaN  NaN       NaN                NaN        NaN  NaN
# 952            NaN  ***  NaN       NaN                NaN  Agreed TB  NaN
# 953            NaN  NaN  NaN       NaN                NaN        NaN  NaN
# 954            NaN  NaN  NaN       NaN                NaN        NaN  NaN
#
# 7   Doc. Date    S   DD  ... Curr Clrng doc. Amt in loc.cur.  LCu Text  \
# ...

# %%
emptyRows = df[df.isnull().all(axis=1)].index

# %%
df.drop(emptyRows,inplace = True)

# %%
df.reset_index(drop=True, inplace = True)

# %%
df
# Out:
# 7           Vendor Name   St Reference         Assignment  DocumentNo  Typ  \
# 0           Vendor  NaN  NaN       NaN              27145         NaN  NaN
# 1     Company Code  NaN  NaN       NaN               3440         NaN  NaN
# 2             Name  NaN  NaN       NaN  Bjorn Thorsen A/S         NaN  NaN
# 3             City  NaN  NaN       NaN           Hellerup         NaN  NaN
# 4              NaN  NaN  NaN   SF90343               f110  3200009005   RE
# ..             ...  ...  ...       ...                ...         ...  ...
# 610           Name  NaN  NaN       NaN                  *         NaN  NaN
# 611           City  NaN  NaN       NaN                  *         NaN  NaN
# 612            NaN  ***  NaN       NaN                NaN   Agreed TB  NaN
# 613            NaN  NaN  NaN       NaN                NaN         NaN  NaN
# 614            NaN  NaN  NaN       NaN                NaN         NaN  NaN
#
# ...

# %%
df["Vendor"] = df["Vendor"].str.strip()

# %%
vendorIndexes = df[df["Vendor"]=="Vendor"].index
nameIndexes = df[df["Vendor"]=="Name"].index

# %%
vendorIndexes
# Out:
# Int64Index([  0,   9,  24,  46,  77,  85,  92, 109, 122, 134, 142, 171, 180,
#             187, 194, 201, 208, 215, 229, 253, 294, 302, 309, 317, 326, 333,
#             340, 359, 370, 382, 390, 400, 435, 442, 458, 474, 481, 490, 497,
#             504, 511, 520, 527, 534, 544, 573, 589, 598, 608],
#            dtype='int64')

# %%
for i in vendorIndexes:
    df.iloc[(i+4),0] = df.iloc[i,4]

# %%
nameIndexes
# Out:
# Int64Index([  2,  11,  26,  48,  79,  87,  94, 111, 124, 136, 144, 173, 182,
#             189, 196, 203, 210, 217, 231, 255, 296, 304, 311, 319, 328, 335,
#             342, 361, 372, 384, 392, 402, 437, 444, 460, 476, 483, 492, 499,
#             506, 513, 522, 529, 536, 546, 575, 591, 600, 610],
#            dtype='int64')

# %%
for i in nameIndexes:
    df.iloc[(i+2),1] = df.iloc[i,4]

# %%
df
# Out:
# 7          Vendor               Name   St Reference         Assignment  \
# 0          Vendor                NaN  NaN       NaN              27145
# 1    Company Code                NaN  NaN       NaN               3440
# 2            Name                NaN  NaN       NaN  Bjorn Thorsen A/S
# 3            City                NaN  NaN       NaN           Hellerup
# 4           27145  Bjorn Thorsen A/S  NaN   SF90343               f110
# ..            ...                ...  ...       ...                ...
# 610          Name                NaN  NaN       NaN                  *
# 611          City                NaN  NaN       NaN                  *
# 612             *                  *  NaN       NaN                NaN
# 613           NaN                NaN  NaN       NaN                NaN
# 614           NaN                NaN  NaN       NaN                NaN
#
# 7    DocumentNo  Typ   Doc. Date    S   DD  ... Curr Clrng doc.  \
# ...

# %%
accountList = []
accountIndexes = df[df["Name"]=="**"].index

# %%
accountIndexes
# Out:
# Int64Index([  8,  23,  45,  76,  84,  91, 108, 121, 133, 141, 170, 179, 186,
#             193, 200, 207, 214, 228, 252, 293, 301, 308, 316, 325, 332, 339,
#             358, 369, 381, 389, 399, 434, 441, 457, 473, 480, 489, 496, 503,
#             510, 519, 526, 533, 543, 572, 588, 597, 606],
#            dtype='int64')

# %%
for i in accountIndexes:
    accountList.append(df.iloc[i,2])

# %%
accountList
# Out:
# ['Account 27145',
#  'Account 27401',
#  'Account 50535',
#  'Account 200509',
#  'Account 200531',
#  'Account 200532',
#  'Account 200580',
#  'Account 34400001',
#  'Account 34400009',
#  'Account 34400045',
#  'Account 34400047',
#  'Account 34400049',
#  'Account 34400058',
#  'Account 34400072',
#  'Account 34400086',
#  'Account 34400112',
#  'Account 34400124',
#  'Account 34400129',
#  'Account 34400141',
#  'Account 34400142',
#  'Account 34400150',
#  'Account 34400157',
#  'Account 34400158',
#  'Account 34400166',
#  'Account 34400179',
#  'Account 34400182',
#  'Account 34400185',
#  'Account 34400187',
#  'Account 34400196',
#  'Account 34400208',
#  'Account 34400229',
#  'Account 34400231',
#  'Account 34400251',
#  'Account 34400284',
#  'Account 34400298',
#  'Account 34400299',
#  'Account 34400302',
#  'Account 34400313',
#  'Account 34400336',
#  'Account 34400343',
#  'Account 34400363',
#  'Account 34400367',
#  'Account 34400368',
#  'Account 34400373',
# ...

# %%
df = df[(df["Name"]!="*") & (df["Name"]!="**")].reset_index(drop=True)

# %%
df.head(15)
# Out:
# 7         Vendor                 Name   St   Reference           Assignment  \
# 0         Vendor                  NaN  NaN         NaN                27145
# 1   Company Code                  NaN  NaN         NaN                 3440
# 2           Name                  NaN  NaN         NaN    Bjorn Thorsen A/S
# 3           City                  NaN  NaN         NaN             Hellerup
# 4          27145    Bjorn Thorsen A/S  NaN     SF90343                 f110
# 5            NaN                  NaN  NaN     SF90344                 f110
# 6            NaN                  NaN  NaN     SF90348                 f110
# 7         Vendor                  NaN  NaN         NaN                27401
# 8   Company Code                  NaN  NaN         NaN                 3440
# 9           Name                  NaN  NaN         NaN  Borealis UK Limited
# 10          City                  NaN  NaN         NaN           Manchester
# ...

# %%
nameIndexes = df[df["Name"].notnull()].index

# %%
nameIndexes
# Out:
# Int64Index([  4,  11,  24,  44,  73,  79,  84,  99, 110, 120, 126, 153, 160,
#             165, 170, 175, 180, 185, 197, 219, 258, 264, 269, 275, 282, 287,
#             292, 309, 318, 328, 334, 342, 375, 380, 394, 408, 413, 420, 425,
#             430, 435, 442, 447, 452, 460, 487, 501, 508],
#            dtype='int64')

# %%
for i in range(0,len(nameIndexes)):
    df.iloc[nameIndexes[i],2] = accountList[i]

# %%
df["Vendor"].values
# Out:
# array(['Vendor', 'Company Code', 'Name', 'City', 27145, nan, nan,
#        'Vendor', 'Company Code', 'Name', 'City', 27401, nan, nan, nan,
#        nan, nan, nan, nan, nan, 'Vendor', 'Company Code', 'Name', 'City',
#        50535, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, 'Vendor', 'Company Code', 'Name', 'City', 200509,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, 'Vendor',
#        'Company Code', 'Name', 'City', 200531, nan, 'Vendor',
#        'Company Code', 'Name', 'City', 200532, 'Vendor', 'Company Code',
#        'Name', 'City', 200580, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, 'Vendor', 'Company Code', 'Name', 'City', 34400001, nan,
#        nan, nan, nan, nan, nan, 'Vendor', 'Company Code', 'Name', 'City',
#        34400009, nan, nan, nan, nan, nan, 'Vendor', 'Company Code',
# ...

# %%
df = df[(df["Vendor"]!="Vendor") & (df["Vendor"]!="Company Code") & (df["Vendor"]!="Name") & (df["Vendor"]!="City")]

# %%
df.reset_index(drop = True, inplace = True)

# %%
df.tail(10)
# Out:
# 7   Vendor                                 Name             St   Reference  \
# 312    NaN                                  NaN            NaN  9330426786
# 313  C4100  Biesterfeld Performance Rubber GmbH  Account C4100  9410009613
# 314    NaN                                  NaN            NaN  9410009721
# 315    NaN                                  NaN            NaN  9410009776
# 316  C9100                       Biesterfeld AG  Account C9100  3001931437
# 317    NaN                                  NaN            NaN  3001931438
# 318    NaN                                  NaN            NaN         NaN
# 319    NaN                                  NaN            NaN         NaN
# 320    NaN                                  NaN            NaN         NaN
# 321    NaN                                  NaN            NaN         NaN
#
# 7   Assignment  DocumentNo  Typ   Doc. Date    S   DD  ... Curr Clrng doc.  \
# ...

# %%
vendor = ""
name = ""
account = ""
vendorList = []
nameList = []
accountList = []
for i in range(0,len(df["Vendor"])):
    currentVendor = df.iloc[i,0]
    currentName = df.iloc[i,1]
    currentAccount = df.iloc[i,2]
    if pd.notnull(currentVendor):
        vendor = currentVendor
        name = currentName
        account = currentAccount
    vendorList.append(vendor)
    nameList.append(name)
    accountList.append(account)

# %%
vendorList
# Out:
# [27145,
#  27145,
#  27145,
#  27401,
#  27401,
#  27401,
#  27401,
#  27401,
#  27401,
#  27401,
#  27401,
#  27401,
#  50535,
#  50535,
#  50535,
#  50535,
#  50535,
#  50535,
#  50535,
#  50535,
#  50535,
#  50535,
#  50535,
#  50535,
#  50535,
#  50535,
#  50535,
#  50535,
#  200509,
#  200509,
#  200509,
#  200509,
#  200509,
#  200509,
#  200509,
#  200509,
#  200509,
#  200509,
#  200509,
#  200509,
#  200509,
#  200509,
#  200509,
#  200509,
#  200509,
#  200509,
#  200509,
#  200509,
#  200509,
#  200509,
#  200509,
#  200509,
#  200509,
#  200531,
#  200531,
#  200532,
#  200580,
#  200580,
#  200580,
#  200580,
#  200580,
#  200580,
#  200580,
#  200580,
#  200580,
#  200580,
#  200580,
#  34400001,
#  34400001,
#  34400001,
#  34400001,
#  34400001,
#  34400001,
#  34400001,
#  34400009,
#  34400009,
#  34400009,
#  34400009,
#  34400009,
#  34400009,
#  34400045,
#  34400045,
#  34400047,
#  34400047,
#  34400047,
#  34400047,
#  34400047,
#  34400047,
#  34400047,
# ...

# %%
df["Vendor"] = vendorList
df["Name"] = nameList
df["St"] = accountList
# Out:
# /tmp/ipykernel_94193/2260034957.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Vendor"] = vendorList
# /tmp/ipykernel_94193/2260034957.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Name"] = nameList
# /tmp/ipykernel_94193/2260034957.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df
# Out:
# 7   Vendor                 Name             St   Reference  Assignment  \
# 0    27145    Bjorn Thorsen A/S  Account 27145     SF90343        f110
# 1    27145    Bjorn Thorsen A/S  Account 27145     SF90344        f110
# 2    27145    Bjorn Thorsen A/S  Account 27145     SF90348        f110
# 3    27401  Borealis UK Limited  Account 27401  5550046238  5550046238
# 4    27401  Borealis UK Limited  Account 27401  5550046239  5550046239
# ..     ...                  ...            ...         ...         ...
# 317  C9100       Biesterfeld AG  Account C9100  3001931438        f110
# 318  C9100       Biesterfeld AG  Account C9100         NaN         NaN
# 319  C9100       Biesterfeld AG  Account C9100         NaN         NaN
# 320  C9100       Biesterfeld AG  Account C9100         NaN         NaN
# 321  C9100       Biesterfeld AG  Account C9100         NaN         NaN
#
# 7    DocumentNo  Typ   Doc. Date    S   DD  ... Curr Clrng doc.  \
# ...

# %%
df.to_excel("Aged Task.xlsx",index = False)
