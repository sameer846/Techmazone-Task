# %%
import pandas as pd
import re

# %%
data = pd.read_excel("GL Transactions as at 31.10.212.xlsx", dtype= str,header=None)

# %%
data = data[6:]

# %%
data.reset_index(drop = True)
# Out:
#                    0        1           2             3   \
# 0        Posting date  Voucher  Dimensions           NaN
# 1      Ledger account    20030         NaN  Account name
# 2          01.01.2021    20/21         NaN           NaN
# 3      Ledger account    20030         NaN           NaN
# 4                 NaN      NaN         NaN           NaN
# ...               ...      ...         ...           ...
# 13283      01.01.2021    20/21         NaN           NaN
# 13284      01.01.2021    20/21         NaN           NaN
# 13285  Ledger account   999000         NaN           NaN
# 13286             NaN      NaN         NaN           NaN
# 13287             NaN      NaN         NaN           NaN
#
#                                           4    5    6   \
# 0                                        NaN  NaN  NaN
# 1      Similar rights an licenses - software  NaN  NaN
# 2                                        NaN  NaN  NaN
# ...

# %%
data.columns = data.iloc[0]
data = data[1:]
data.reset_index(drop = True)
# Out:
# 6        Posting date Voucher Dimensions           NaN  \
# 0      Ledger account   20030        NaN  Account name
# 1          01.01.2021   20/21        NaN           NaN
# 2      Ledger account   20030        NaN           NaN
# 3                 NaN     NaN        NaN           NaN
# 4                 NaN     NaN        NaN           NaN
# ...               ...     ...        ...           ...
# 13282      01.01.2021   20/21        NaN           NaN
# 13283      01.01.2021   20/21        NaN           NaN
# 13284  Ledger account  999000        NaN           NaN
# 13285             NaN     NaN        NaN           NaN
# 13286             NaN     NaN        NaN           NaN
#
# 6                                        NaN  NaN  NaN  \
# 0      Similar rights an licenses - software  NaN  NaN
# 1                                        NaN  NaN  NaN
# 2                                        NaN  NaN  NaN
# 3                                        NaN  NaN  NaN
# ...

# %%
data.reset_index(drop = True,inplace= True)
data
# Out:
# 6        Posting date Voucher Dimensions           NaN  \
# 0      Ledger account   20030        NaN  Account name
# 1          01.01.2021   20/21        NaN           NaN
# 2      Ledger account   20030        NaN           NaN
# 3                 NaN     NaN        NaN           NaN
# 4                 NaN     NaN        NaN           NaN
# ...               ...     ...        ...           ...
# 13282      01.01.2021   20/21        NaN           NaN
# 13283      01.01.2021   20/21        NaN           NaN
# 13284  Ledger account  999000        NaN           NaN
# 13285             NaN     NaN        NaN           NaN
# 13286             NaN     NaN        NaN           NaN
#
# 6                                        NaN  NaN  NaN  \
# 0      Similar rights an licenses - software  NaN  NaN
# 1                                        NaN  NaN  NaN
# 2                                        NaN  NaN  NaN
# 3                                        NaN  NaN  NaN
# ...

# %%
datePattern  = r"\d.\d+.\d+"

# %%
nulls = pd.isnull(data["Posting date"]).values

# %%
nulls = [i for i,x in enumerate(nulls) if x]

# %%
nulls
# Out:
# [3,
#  4,
#  8,
#  9,
#  19,
#  20,
#  47,
#  48,
#  49,
#  50,
#  51,
#  105,
#  106,
#  107,
#  108,
#  109,
#  163,
#  164,
#  165,
#  166,
#  167,
#  174,
#  175,
#  180,
#  181,
#  218,
#  219,
#  220,
#  221,
#  222,
#  276,
#  277,
#  278,
#  279,
#  280,
#  294,
#  295,
#  299,
#  300,
#  304,
#  305,
#  310,
#  311,
#  325,
#  326,
#  327,
#  328,
#  329,
#  331,
#  333,
#  334,
#  340,
#  341,
#  379,
#  380,
#  381,
#  382,
#  383,
#  395,
#  396,
#  401,
#  402,
#  434,
#  435,
#  436,
#  437,
#  438,
#  492,
#  493,
#  494,
#  495,
#  496,
#  550,
#  551,
#  552,
#  553,
#  554,
#  568,
#  569,
#  583,
#  584,
#  605,
#  606,
#  607,
#  608,
#  609,
#  663,
#  664,
#  665,
#  666,
#  667,
#  721,
#  722,
#  723,
#  724,
#  725,
#  779,
#  780,
#  781,
#  782,
#  783,
#  837,
#  838,
#  839,
#  840,
#  841,
#  895,
#  896,
#  897,
#  898,
#  899,
#  910,
#  911,
#  951,
#  952,
#  953,
#  954,
#  955,
#  1002,
#  1003,
#  1007,
#  1008,
#  1009,
#  1010,
#  1011,
# ...

# %%
data.reset_index(drop = True)
data.drop(index=nulls, inplace = True)
data.reset_index(drop = True)
# Out:
# 6        Posting date Voucher Dimensions           NaN  \
# 0      Ledger account   20030        NaN  Account name
# 1          01.01.2021   20/21        NaN           NaN
# 2      Ledger account   20030        NaN           NaN
# 3      Ledger account   20035        NaN  Account name
# 4          01.01.2021   20/21        NaN           NaN
# ...               ...     ...        ...           ...
# 11839  Ledger account  999000        NaN  Account name
# 11840      01.01.2021   20/21        NaN           NaN
# 11841      01.01.2021   20/21        NaN           NaN
# 11842      01.01.2021   20/21        NaN           NaN
# 11843  Ledger account  999000        NaN           NaN
#
# 6                                                    NaN  NaN  NaN  \
# 0                  Similar rights an licenses - software  NaN  NaN
# 1                                                    NaN  NaN  NaN
# 2                                                    NaN  NaN  NaN
# ...

# %%
data= data[data["Posting date"].str.contains(datePattern)]

# %%
data.reset_index(drop = True, inplace= True)

# %%
data
# Out:
# 6     Posting date Voucher Dimensions  NaN  NaN  NaN  NaN  \
# 0       01.01.2021   20/21        NaN  NaN  NaN  NaN  NaN
# 1       01.01.2021   20/21        NaN  NaN  NaN  NaN  NaN
# 2       01.01.2021   20/21        NaN  NaN  NaN  NaN  NaN
# 3       31.10.2021    3806        NaN  900  NaN  NaN  NaN
# 4       31.10.2021    3807        NaN  900  NaN  NaN  NaN
# ...            ...     ...        ...  ...  ...  ...  ...
# 11105   30.09.2021    3781        NaN  900  NaN  NaN  NaN
# 11106   31.10.2021    3796        NaN  900  NaN  NaN  NaN
# 11107   01.01.2021   20/21        NaN  NaN  NaN  NaN  NaN
# 11108   01.01.2021   20/21        NaN  NaN  NaN  NaN  NaN
# 11109   01.01.2021   20/21        NaN  NaN  NaN  NaN  NaN
#
# 6                    Transaction text Currency Currency amount      Amount  \
# 0      Opening transaction 17.02.2021      GBP          637,00      637,00
# 1      Opening transaction 17.02.2021      GBP         -637,00      637,00
# ...

# %%
x = data["Currency amount"].replace(",","*")

# %%
x = x.str.replace(",","*")

# %%
x = x.str.replace(".",",")
# Out:
# /tmp/ipykernel_6467/673352148.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   x = x.str.replace(".",",")

# %%
x = x.str.replace("*",".")
# Out:
# /tmp/ipykernel_6467/931800292.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   x = x.str.replace("*",".")

# %%
data["Currency amount"] = x
# Out:
# /tmp/ipykernel_6467/916453098.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Currency amount"] = x

# %%
data.head(20)
# Out:
# 6  Posting date    Voucher Dimensions  NaN  NaN  NaN  NaN  \
# 0    01.01.2021      20/21        NaN  NaN  NaN  NaN  NaN
# 1    01.01.2021      20/21        NaN  NaN  NaN  NaN  NaN
# 2    01.01.2021      20/21        NaN  NaN  NaN  NaN  NaN
# 3    31.10.2021       3806        NaN  900  NaN  NaN  NaN
# 4    31.10.2021       3807        NaN  900  NaN  NaN  NaN
# 5    31.10.2021       3808        NaN  900  NaN  NaN  NaN
# 6    31.10.2021       3809        NaN  900  NaN  NaN  NaN
# 7    31.10.2021       3810        NaN  900  NaN  NaN  NaN
# 8    31.10.2021       3811        NaN  900  NaN  NaN  NaN
# 9    01.01.2021      20/21        NaN  NaN  NaN  NaN  NaN
# 10   31.01.2021  FA-005411        NaN  900  NaN  NaN  NaN
# 11   31.01.2021  FA-005412        NaN  900  NaN  NaN  NaN
# 12   31.01.2021  FA-005413        NaN  900  NaN  NaN  NaN
# 13   31.01.2021  FA-005414        NaN  900  NaN  NaN  NaN
# 14   31.01.2021  FA-005415        NaN  900  NaN  NaN  NaN
# ...
