# %%
import pandas as pd
import csv

# %%
dataframe = pd.read_table("KE UK GLs 2021.txt",delimiter="|")
# Out:
# /tmp/ipykernel_93763/3536047222.py:1: DtypeWarning: Columns (0,15,19,24,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataframe = pd.read_table("KE UK GLs 2021.txt",delimiter="|")

# %%
dataframe
# Out:
#       Entry No. G/L Account No. Posting Date Document Type Document No.  \
# 0        464794           02503     01/01/21                        GIT
# 1        464795           27200     01/01/21                        GIT
# 2        464796           02502     01/01/21                        GIT
# 3        464797           27300     01/01/21                        GIT
# 4        464807           26190     01/01/21                 PURCH ACCL
# ...         ...             ...          ...           ...          ...
# 28773  494124.0           05100     31/12/21       Payment           DD
# 28774  494140.0           05100     31/12/21       Invoice    K-PI28636
# 28775  494141.0           06500     31/12/21                     DT ADJ
# 28776  494142.0           06500     31/12/21                     DT ADJ
# 28777  494143.0           63500     31/12/21                     DT ADJ
#
#                   Description Bal. Account No.     Amount  \
# ...

# %%
dataset = dataframe.values.tolist()

# %%
dataset
# Out:
# [['464794',
#   '02503',
#   '01/01/21',
#   ' ',
#   'GIT',
#   'December GIT',
#   nan,
#   '-4,381',
#   'K100',
#   nan,
#   'SARAH.JONES',
#   'GENJNL',
#   'No',
#   'No',
#   nan,
#   0.0,
#   '0',
#   nan,
#   'GIT',
#   nan,
#   ' ',
#   nan,
#   nan,
#   'G/L Account',
#   123297.0,
#   '0',
#   '4,381',
#   '31/12/20',
#   nan,
#   ' ',
#   nan,
#   nan,
#   nan,
#   'No',
#   nan,
#   'No',
#   nan,
#   nan,
#   0.0,
#   0.0,
#   0.0,
#   0.0,
#   nan,
#   'No',
#   0.0,
#   0.0,
#   nan,
#   ' ',
#   0.0,
#   nan,
#   'K100',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['464795',
#   '27200',
#   '01/01/21',
#   ' ',
#   'GIT',
#   'December GIT',
#   nan,
#   '4,381',
#   'K100',
#   nan,
#   'SARAH.JONES',
#   'GENJNL',
#   'No',
#   'No',
#   nan,
#   0.0,
#   '0',
#   nan,
#   'GIT',
#   nan,
#   ' ',
#   nan,
#   nan,
#   'G/L Account',
#   123297.0,
#   '4,381',
#   '0',
# ...

# %%
for i in dataset:
    try:
        i[0] = int(i[0])
    except:
        print(i[0])
# Out:
# CAR MILEAGE OVER JAN-DEC 2020
# CAR MILEAGE OVER JAN-DEC 2020
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# Contract No 135751, 28/10/2021
# Contract No 135751, 28/10/2021
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan

# %%
i = 0
while True:
    if(i>=len(dataset)):
        break
    try:
        dataset[i][0] = int(dataset[i][0])
    except:
        print(dataset[i][0])
        del dataset[i]
        i-=1
    i+=1
# Out:
# CAR MILEAGE OVER JAN-DEC 2020
# CAR MILEAGE OVER JAN-DEC 2020
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# Contract No 135751, 28/10/2021
# Contract No 135751, 28/10/2021
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan

# %%
df = pd.DataFrame(dataset)

# %%
df
# Out:
#            0      1         2        3           4                       5   \
# 0      464794  02503  01/01/21                  GIT            December GIT
# 1      464795  27200  01/01/21                  GIT            December GIT
# 2      464796  02502  01/01/21                  GIT            December GIT
# 3      464797  27300  01/01/21                  GIT            December GIT
# 4      464807  26190  01/01/21           PURCH ACCL  Davies Turner PO 28993
# ...       ...    ...       ...      ...         ...                     ...
# 28655  494124  05100  31/12/21  Payment          DD        BARCLAYCARD - DD
# 28656  494140  05100  31/12/21  Invoice   K-PI28636       Invoice K-PI28636
# 28657  494141  06500  31/12/21               DT ADJ    Corporation Tax 2021
# 28658  494142  06500  31/12/21               DT ADJ    Corporation Tax 2021
# 28659  494143  63500  31/12/21               DT ADJ    Corporation Tax 2021
#
# ...

# %%
for i in dataset:
    del i[14:16]

# %%
for i in dataset:
    del i[15]

# %%
for i in dataset:
    print(len(i))
    break
# Out:
# 63

# %%
dataset[23]
# Out:
# [464830,
#  '10920',
#  '04/01/21',
#  'Invoice',
#  '21SI1001',
#  'Order 20SO1827',
#  nan,
#  '-280',
#  'K200',
#  'EU OLD',
#  'PHIL.BUTLER',
#  'SALES',
#  'Yes',
#  'No',
#  '0',
#  nan,
#  nan,
#  'Sale',
#  'EUR',
#  'K200',
#  'G/L Account',
#  123304.0,
#  '0',
#  '280',
#  '04/01/21',
#  '4688',
#  'Customer',
#  'K-A1036',
#  'SALES',
#  nan,
#  'No',
#  nan,
#  'No',
#  'EU',
#  '20%',
#  0.0,
#  0.0,
#  0.0,
#  0.0,
#  nan,
#  'No',
#  0.0,
#  0.0,
#  nan,
#  ' ',
#  0.0,
#  nan,
#  'K200',
#  'EU OLD',
#  '_THIRD',
#  nan,
#  'EFB',
#  'NEW',
#  'ACCOUNTS',
#  'THIRD',
#  'NONE',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan]

# %%
for i in dataset:
    del i[-1]
    del i[-1]
    del i[-1]
    del i[-1]
    del i[-1]

# %%
for i in dataset:
    del i[-2]

# %%
for i in dataset:
    del i[35:47]

# %%
dataset
# Out:
# [[464794,
#   '02503',
#   '01/01/21',
#   ' ',
#   'GIT',
#   'December GIT',
#   nan,
#   '-4,381',
#   'K100',
#   nan,
#   'SARAH.JONES',
#   'GENJNL',
#   'No',
#   'No',
#   '0',
#   'GIT',
#   nan,
#   ' ',
#   nan,
#   nan,
#   'G/L Account',
#   123297.0,
#   '0',
#   '4,381',
#   '31/12/20',
#   nan,
#   ' ',
#   nan,
#   nan,
#   nan,
#   'No',
#   nan,
#   'No',
#   nan,
#   nan,
#   'K100',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  [464795,
#   '27200',
#   '01/01/21',
#   ' ',
#   'GIT',
#   'December GIT',
#   nan,
#   '4,381',
#   'K100',
#   nan,
#   'SARAH.JONES',
#   'GENJNL',
#   'No',
#   'No',
#   '0',
#   'GIT',
#   nan,
#   ' ',
#   nan,
#   nan,
#   'G/L Account',
#   123297.0,
#   '4,381',
#   '0',
#   '31/12/20',
#   nan,
#   ' ',
#   nan,
#   nan,
#   nan,
#   'No',
#   nan,
#   'No',
#   nan,
#   nan,
#   'K100',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  [464796,
# ...

# %%
for i in dataset:
    del i[31]

# %%
for i in dataset:
    print(len(i))
    break
# Out:
# 44

# %%
dataset[23]
# Out:
# [464830,
#  '10920',
#  '04/01/21',
#  'Invoice',
#  '21SI1001',
#  'Order 20SO1827',
#  nan,
#  '-280',
#  'K200',
#  'EU OLD',
#  'PHIL.BUTLER',
#  'SALES',
#  'Yes',
#  'No',
#  '0',
#  nan,
#  nan,
#  'Sale',
#  'EUR',
#  'K200',
#  'G/L Account',
#  123304.0,
#  '0',
#  '280',
#  '04/01/21',
#  '4688',
#  'Customer',
#  'K-A1036',
#  'SALES',
#  nan,
#  'No',
#  'No',
#  'EU',
#  '20%',
#  'K200',
#  'EU OLD',
#  '_THIRD',
#  nan,
#  'EFB',
#  'NEW',
#  'ACCOUNTS',
#  'THIRD',
#  'NONE',
#  nan]

# %%
for i in dataset:
    del i[37]

# %%
dataset[23]
# Out:
# [464830,
#  '10920',
#  '04/01/21',
#  'Invoice',
#  '21SI1001',
#  'Order 20SO1827',
#  nan,
#  '-280',
#  'K200',
#  'EU OLD',
#  'PHIL.BUTLER',
#  'SALES',
#  'Yes',
#  'No',
#  '0',
#  nan,
#  nan,
#  'Sale',
#  'EUR',
#  'K200',
#  'G/L Account',
#  123304.0,
#  '0',
#  '280',
#  '04/01/21',
#  '4688',
#  'Customer',
#  'K-A1036',
#  'SALES',
#  nan,
#  'No',
#  'No',
#  'EU',
#  '20%',
#  'K200',
#  'EU OLD',
#  '_THIRD',
#  'EFB',
#  'NEW',
#  'ACCOUNTS',
#  'THIRD',
#  'NONE',
#  nan]

# %%
for i in dataset:
    del i[16]

# %%
dataset[23]
# Out:
# [464830,
#  '10920',
#  '04/01/21',
#  'Invoice',
#  '21SI1001',
#  'Order 20SO1827',
#  nan,
#  '-280',
#  'K200',
#  'EU OLD',
#  'PHIL.BUTLER',
#  'SALES',
#  'Yes',
#  'No',
#  '0',
#  nan,
#  'Sale',
#  'EUR',
#  'K200',
#  'G/L Account',
#  123304.0,
#  '0',
#  '280',
#  '04/01/21',
#  '4688',
#  'Customer',
#  'K-A1036',
#  'SALES',
#  nan,
#  'No',
#  'No',
#  'EU',
#  '20%',
#  'K200',
#  'EU OLD',
#  '_THIRD',
#  'EFB',
#  'NEW',
#  'ACCOUNTS',
#  'THIRD',
#  'NONE',
#  nan]

# %%
for i in dataset:
    del i[28]

# %%
len(dataset[0])
# Out:
# 41

# %%
header = ["Entry No.","G/L Account No.","Posting Date","Document Type","Document No.","Description","Bal. Account No.","Amount","Global Dimension 1 Code","Global Dimension 2 Code","User ID","Source Code","System-Created Entry","Prior-Year Entry","VAT Amount","Journal Batch Name","Gen. Posting Type","Gen. Bus. Posting Group","Gen. Prod. Posting Group","Bal. Account Type","Transaction No.","Debit Amount","Credit Amount","Document Date","External Document No.","Source Type","Source No.","No. Series","Tax Liable","Use Tax","VAT Bus. Posting Group","VAT Prod. Posting Group","BM Dim PRODUCTGROUP","BM Dim AREA","BM Dim BUSINESSREL","BM Dim BRANCH","BM Dim ORDERTYPE","BM Dim SALESPERSON","BM Dim CONSOLIDATION","BM Dim KEYACCOUNT","BM Dim COSTCENTRE"]

# %%
df = pd.DataFrame(dataset,columns=header)

# %%
df
# Out:
#        Entry No. G/L Account No. Posting Date Document Type Document No.  \
# 0         464794           02503     01/01/21                        GIT
# 1         464795           27200     01/01/21                        GIT
# 2         464796           02502     01/01/21                        GIT
# 3         464797           27300     01/01/21                        GIT
# 4         464807           26190     01/01/21                 PURCH ACCL
# ...          ...             ...          ...           ...          ...
# 28655     494124           05100     31/12/21       Payment           DD
# 28656     494140           05100     31/12/21       Invoice    K-PI28636
# 28657     494141           06500     31/12/21                     DT ADJ
# 28658     494142           06500     31/12/21                     DT ADJ
# 28659     494143           63500     31/12/21                     DT ADJ
#
#                   Description Bal. Account No.     Amount  \
# ...

# %%
df.to_excel("Task_1_Final.xlsx",index=False)
