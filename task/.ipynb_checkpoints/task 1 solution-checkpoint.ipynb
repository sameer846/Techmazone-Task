# %%
import pandas as pd

# %%
ds = pd.read_table("KE UK GLs 2021.txt",header = None)

# %%
ds
# Out:
#                                                        0
# 0      Entry No.|G/L Account No.|Posting Date|Documen...
# 1      464794|02503|01/01/21| |GIT|December GIT||-4,3...
# 2      464795|27200|01/01/21| |GIT|December GIT||4,38...
# 3      464796|02502|01/01/21| |GIT|December GIT||-5,7...
# 4      464797|27300|01/01/21| |GIT|December GIT||5,77...
# ...                                                  ...
# 28774  494124|05100|31/12/21|Payment|DD|BARCLAYCARD -...
# 28775  494140|05100|31/12/21|Invoice|K-PI28636|Invoic...
# 28776  494141|06500|31/12/21| |DT ADJ|Corporation Tax...
# 28777  494142|06500|31/12/21| |DT ADJ|Corporation Tax...
# 28778  494143|63500|31/12/21| |DT ADJ|Corporation Tax...
#
# [28779 rows x 1 columns]

# %%
ds = ds[0].str.split("|",expand = True)

# %%
ds
# Out:
#               0                1             2              3             4   \
# 0      Entry No.  G/L Account No.  Posting Date  Document Type  Document No.
# 1         464794            02503      01/01/21                          GIT
# 2         464795            27200      01/01/21                          GIT
# 3         464796            02502      01/01/21                          GIT
# 4         464797            27300      01/01/21                          GIT
# ...          ...              ...           ...            ...           ...
# 28774     494124            05100      31/12/21        Payment            DD
# 28775     494140            05100      31/12/21        Invoice     K-PI28636
# 28776     494141            06500      31/12/21                       DT ADJ
# 28777     494142            06500      31/12/21                       DT ADJ
# 28778     494143            63500      31/12/21                       DT ADJ
#
# ...

# %%
df = pd.DataFrame(ds.iloc[1:].values,columns = ds.iloc[0].values)

# %%
df
# Out:
#       Entry No. G/L Account No. Posting Date Document Type Document No.  \
# 0        464794           02503     01/01/21                        GIT
# 1        464795           27200     01/01/21                        GIT
# 2        464796           02502     01/01/21                        GIT
# 3        464797           27300     01/01/21                        GIT
# 4        464807           26190     01/01/21                 PURCH ACCL
# ...         ...             ...          ...           ...          ...
# 28773    494124           05100     31/12/21       Payment           DD
# 28774    494140           05100     31/12/21       Invoice    K-PI28636
# 28775    494141           06500     31/12/21                     DT ADJ
# 28776    494142           06500     31/12/21                     DT ADJ
# 28777    494143           63500     31/12/21                     DT ADJ
#
#                   Description Bal. Account No.     Amount  \
# ...
