# %%
import pandas as pd

# %%
data15 = pd.read_csv("World_Happiness_2015.csv")

# %%
data15
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
countries = list(data15["Country"].head(10).values)
countries
# Out:
# ['Switzerland',
#  'Iceland',
#  'Denmark',
#  'Norway',
#  'Canada',
#  'Finland',
#  'Netherlands',
#  'Sweden',
#  'New Zealand',
#  'Australia']

# %%
data16 = pd.read_csv("World_Happiness_2016.csv")
col = ['Country', 'Happiness Rank', 'Happiness Score',
       'Lower Confidence Interval', 'Upper Confidence Interval',
       'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
       'Freedom', 'Generosity','Trust (Government Corruption)',
       'Dystopia Residual']
data17 = pd.read_csv("World_Happiness_2017.csv")
data17.columns = col

# %%
datafif = data.iloc[0]
datasix = data.iloc[1]

# %%
lists = []
for i in col:
    if datasix[i]<datafif[i] and i!="Happiness Score":
        lists.append(i)

# %%
d15 = data15[data15["Country"]==i]
d15
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738

# %%
df = pd.DataFrame(data = None,columns=["Country","Year","Affect"])

lists = []
for i in countries:
#     data = pd.DataFrame(columns=col)
    d15 = data15[data15["Country"]==i]
    d16 = data16[data16["Country"]==i]
    d17 = data17[data17["Country"]==i]
    data = pd.concat([d15,d16,d17]).reset_index(drop = True)
    dt15 = data.iloc[0]
    dt16 = data.iloc[1]
    dt17 = data.iloc[2]
    if dt15['Happiness Rank'] < dt16['Happiness Rank']:
        for j in col:
            if dt15[j]<dt16[j] and j!="Happiness Score" and j!="Happiness Rank":
                lists.append(j)
        df = df.append({"Country":i , "Year":16 , "Affect":lists},ignore_index=True)
    lists = []
    if dt16['Happiness Rank'] < dt17['Happiness Rank']:
        for j in col:
            if dt16[j]<dt17[j] and j!="Happiness Score" and j!="Happiness Rank":
                lists.append(j)
        df = df.append({"Country":i , "Year":17 , "Affect":lists},ignore_index=True)
# Out:
# /tmp/ipykernel_87159/3287657475.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"Country":i , "Year":16 , "Affect":lists},ignore_index=True)
# /tmp/ipykernel_87159/3287657475.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"Country":i , "Year":17 , "Affect":lists},ignore_index=True)
# /tmp/ipykernel_87159/3287657475.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"Country":i , "Year":16 , "Affect":lists},ignore_index=True)
# /tmp/ipykernel_87159/3287657475.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
df
# Out:
#        Country Year                                             Affect
# 0  Switzerland   16      [Economy (GDP per Capita), Dystopia Residual]
# 1  Switzerland   17  [Lower Confidence Interval, Economy (GDP per C...
# 2      Iceland   16  [Lower Confidence Interval, Economy (GDP per C...
# 3      Denmark   17  [Lower Confidence Interval, Economy (GDP per C...
# 4       Canada   16      [Economy (GDP per Capita), Dystopia Residual]
# 5       Canada   17  [Lower Confidence Interval, Economy (GDP per C...
# 6       Sweden   16  [Economy (GDP per Capita), Generosity, Dystopi...
# 7    Australia   17  [Lower Confidence Interval, Economy (GDP per C...

# %%
data1.head(15)
# Out:
#           Country                           Region  Happiness Rank  \
# 0     Switzerland                   Western Europe               1
# 1         Iceland                   Western Europe               2
# 2         Denmark                   Western Europe               3
# 3          Norway                   Western Europe               4
# 4          Canada                    North America               5
# 5         Finland                   Western Europe               6
# 6     Netherlands                   Western Europe               7
# 7          Sweden                   Western Europe               8
# 8     New Zealand        Australia and New Zealand               9
# 9       Australia        Australia and New Zealand              10
# 10         Israel  Middle East and Northern Africa              11
# 11     Costa Rica      Latin America and Caribbean              12
# 12        Austria                   Western Europe              13
# ...

# %%
    i = "Denmark"
    d15 = data15[data15["Country"]==i]
    d16 = data16[data16["Country"]==i]
    d17 = data17[data17["Country"]==i]
    data = pd.concat([d15,d16,d17]).reset_index(drop = True)
    dt15 = data.iloc[0]
    dt16 = data.iloc[1]
    dt17 = data.iloc[2]

# %%
data
# Out:
#    Country          Region  Happiness Rank  Happiness Score  Standard Error  \
# 0  Denmark  Western Europe               3            7.527         0.03328
# 1  Denmark  Western Europe               1            7.526             NaN
# 2  Denmark             NaN               2            7.522             NaN
#
#    Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 0                  1.325480  1.360580                  0.874640  0.649380
# 1                  1.441780  1.163740                  0.795040  0.579410
# 2                  1.482383  1.551122                  0.792566  0.626007
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual  \
# 0                        0.48357     0.34139           2.492040
# 1                        0.44453     0.36171           2.739390
# 2                        0.40077     0.35528           2.313707
#
#    Lower Confidence Interval  Upper Confidence Interval
# ...
