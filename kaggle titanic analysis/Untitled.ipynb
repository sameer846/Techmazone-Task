# %%
import csv
openFile = open("train.csv")
readFile = csv.reader(openFile)
data = list(readFile)

# %%
data
# Out:
# [['PassengerId',
#   'Survived',
#   'Pclass',
#   'Name',
#   'Sex',
#   'Age',
#   'SibSp',
#   'Parch',
#   'Ticket',
#   'Fare',
#   'Cabin',
#   'Embarked'],
#  ['1',
#   '0',
#   '3',
#   'Braund, Mr. Owen Harris',
#   'male',
#   '22',
#   '1',
#   '0',
#   'A/5 21171',
#   '7.25',
#   '',
#   'S'],
#  ['2',
#   '1',
#   '1',
#   'Cumings, Mrs. John Bradley (Florence Briggs Thayer)',
#   'female',
#   '38',
#   '1',
#   '0',
#   'PC 17599',
#   '71.2833',
#   'C85',
#   'C'],
#  ['3',
#   '1',
#   '3',
#   'Heikkinen, Miss. Laina',
#   'female',
#   '26',
#   '0',
#   '0',
#   'STON/O2. 3101282',
#   '7.925',
#   '',
#   'S'],
#  ['4',
#   '1',
#   '1',
#   'Futrelle, Mrs. Jacques Heath (Lily May Peel)',
#   'female',
#   '35',
#   '1',
#   '0',
#   '113803',
#   '53.1',
#   'C123',
#   'S'],
#  ['5',
#   '0',
#   '3',
#   'Allen, Mr. William Henry',
#   'male',
#   '35',
#   '0',
#   '0',
#   '373450',
#   '8.05',
#   '',
#   'S'],
#  ['6',
#   '0',
#   '3',
# ...

# %%
header = data[0]
dataset = data[1:]

# %%
header
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
for i in dataset:
    age = i[5]
    if age == "":
        age = 0
    i[5] = int(float(age))

# %%
dict = {}
survivedDict = {}
dict['male']=0
dict['female'] = 0
survivedDict['male']=0
survivedDict['female'] = 0
for i in dataset:
    dict[i[4]]+=1
    if(i[1]=='1'):
        survivedDict[i[4]]+=1

# %%
dict
# Out:
# {'male': 577, 'female': 314}

# %%
survivedDict
# Out:
# {'male': 109, 'female': 233}

# %%
male18 = 0
for i in dataset:
    if(i[1]=='1' and i[4]=='male' and i[5]>=60):
        male18+=1

# %%
109/233
# Out:
# 0.4678111587982833
